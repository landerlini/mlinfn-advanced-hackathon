# %% [markdown]
# # Training the UNET

# %% [markdown]
# We have defined the data generator, the architecture, the loss function and the metric we are going to use. Now, we put all the pieces together to train our U-Net. First, we import the libraries we need for the training.

# %%
import numpy as np
import tensorflow as tf
import json
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
os.environ["CUDA_VISIBLE_DEVICES"]="0"
from glob import glob

from tensorflow.keras import initializers, regularizers, constraints, optimizers, metrics
from tensorflow.keras import backend as K
from tensorflow.keras.activations import softmax
from tensorflow.keras.layers import Dense, Input, Conv2D, Conv2DTranspose, Dropout, Flatten, BatchNormalization, Concatenate, Lambda, Activation, Reshape, Layer, InputSpec
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.utils import Sequence

# NB the following calls depend on the name you gave to .py files and functions
import Data_Generator.DataGenerator as DG
import Loss_Metrics.LossMetrics 
import UNet_Arch.UNET_architecture as unet

tf.keras.backend.clear_session()

# %% [markdown]
# We set the path and the names of the data set.

# %%
dim = 128  # Available dimensions: 128, 256, 512

# Allow for overriding in tests
dim = os.environ.get("UNET_SHEZEN_DIM", dim)

data_url = {128: '0e1e5d/dl/Shezen_128128.zip', 256: '3a4a44/dl/Shezen_256256.zip', 512: '80a4eb/dl/Shezen_512512.zip'}

if not os.path.exists(f"./Shezen_{dim:d}{dim:d}"):
    !  wget https://pandora.infn.it/public/{data_url[dim]} -qO tmp.zip
    ! unzip -q tmp.zip 
    ! rm -rf tmp.zip

path='./Shezen_{:d}{:d}/'.format(dim,dim) # input images path
data_path= path + '*'
# Out:
# data already downloaded
# mkdir: cannot create directory ‘../results’: File exists

# %% [markdown]
# We downloaded the data, now we split them into training, validation and test set. Please leave the data partition as written such that each group will test their architecture on the same test set.
#
# In the following cell you have to set the data generator for both the training and the validation set.

# %%
data_list = [os.path.basename(f) for f in glob(data_path)] 

train_list = data_list[0:500]
val_list = data_list[500:590]
test_list = data_list[590:]

training_gen =
validation_gen =

# %% [markdown]
# # Callbacks for training
#
# As you may know, we can use some built-in callbacks that help to train the network.
#
# ModelCheckPoint is used to save the weights at the epoch with the best validation metric. You need to create a folder named 'results'. You can read the documentation [here](https://keras.io/api/callbacks/model_checkpoint/).
#
# ReduceLROnPlateau is used to decrease the learning rate during training. You can read the documentation [here](https://keras.io/api/callbacks/reduce_lr_on_plateau/).
#
# We define also the optimizer.

# %%
#checkpoint_path="../results/weights-{epoch:03d}-{loss:.2f}-{DSC:.2f}.hdf5" # intermediate weight save path
checkpoint_path_val="../results/weights-val-{epoch:03d}-{loss:.2f}-{val_DSC:.2f}.hdf5"  # intermediate weigth save path

#check=ModelCheckpoint(filepath=checkpoint_path, monitor='loss', verbose=0, save_best_only=True, save_weights_only=True, mode='auto', save_freq='epoch') # Checkpoints parameters
check_val=ModelCheckpoint(filepath=checkpoint_path_val, monitor='val_DSC', verbose=0, save_best_only=True, save_weights_only=True, mode='max')

reduce_lr = ReduceLROnPlateau(monitor='val_DSC', factor=0.5, patience=8, min_lr=0.000005, verbose= True)

adamlr = optimizers.Adam(learning_rate=0.0001, beta_1=0.9, beta_2=0.999, epsilon=1e-08, amsgrad=True)

# %% [markdown]
# Call the U_Net architecture, compile and train it.

# %%
......

with open('history.json', 'w') as f:
    json.dump(str(history.history), f)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 128, 128, 1  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 128, 128, 8)  16          ['input_1[0][0]']
#
#  batch_normalization (BatchNorm  (None, 128, 128, 8)  32         ['conv2d[0][0]']
#  alization)
#
#  activation (Activation)        (None, 128, 128, 8)  0           ['batch_normalization[0][0]']
#
#  spatial_dropout2d (SpatialDrop  (None, 128, 128, 8)  0          ['activation[0][0]']
#  out2D)
#
#  conv2d_1 (Conv2D)              (None, 128, 128, 8)  584         ['spatial_dropout2d[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 128, 128, 8)  32         ['conv2d_1[0][0]']
#  rmalization)
#
#  activation_1 (Activation)      (None, 128, 128, 8)  0           ['batch_normalization_1[0][0]']
#
#  spatial_dropout2d_1 (SpatialDr  (None, 128, 128, 8)  0          ['activation_1[0][0]']
#  opout2D)
#
#  conv2d_2 (Conv2D)              (None, 128, 128, 8)  72          ['spatial_dropout2d_1[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 128, 128, 8)  32         ['conv2d_2[0][0]']
#  rmalization)
#
#  add (Add)                      (None, 128, 128, 8)  0           ['batch_normalization_2[0][0]',
#                                                                   'batch_normalization[0][0]']
#
#  activation_2 (Activation)      (None, 128, 128, 8)  0           ['add[0][0]']
#
#  spatial_dropout2d_2 (SpatialDr  (None, 128, 128, 8)  0          ['activation_2[0][0]']
#  opout2D)
#
#  conv2d_3 (Conv2D)              (None, 64, 64, 16)   528         ['spatial_dropout2d_2[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 64, 64, 16)  64          ['conv2d_3[0][0]']
#  rmalization)
#
#  activation_3 (Activation)      (None, 64, 64, 16)   0           ['batch_normalization_3[0][0]']
#
#  spatial_dropout2d_3 (SpatialDr  (None, 64, 64, 16)  0           ['activation_3[0][0]']
#  opout2D)
#
#  conv2d_4 (Conv2D)              (None, 64, 64, 16)   2320        ['spatial_dropout2d_3[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 64, 64, 16)  64          ['conv2d_4[0][0]']
#  rmalization)
#
#  activation_4 (Activation)      (None, 64, 64, 16)   0           ['batch_normalization_4[0][0]']
#
#  spatial_dropout2d_4 (SpatialDr  (None, 64, 64, 16)  0           ['activation_4[0][0]']
#  opout2D)
#
#  conv2d_5 (Conv2D)              (None, 64, 64, 16)   272         ['spatial_dropout2d_4[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 64, 64, 16)  64          ['conv2d_5[0][0]']
#  rmalization)
#
#  add_1 (Add)                    (None, 64, 64, 16)   0           ['batch_normalization_5[0][0]',
#                                                                   'batch_normalization_3[0][0]']
#
#  activation_5 (Activation)      (None, 64, 64, 16)   0           ['add_1[0][0]']
#
#  spatial_dropout2d_5 (SpatialDr  (None, 64, 64, 16)  0           ['activation_5[0][0]']
#  opout2D)
#
#  conv2d_6 (Conv2D)              (None, 32, 32, 32)   2080        ['spatial_dropout2d_5[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 32, 32, 32)  128         ['conv2d_6[0][0]']
#  rmalization)
#
#  activation_6 (Activation)      (None, 32, 32, 32)   0           ['batch_normalization_6[0][0]']
#
#  spatial_dropout2d_6 (SpatialDr  (None, 32, 32, 32)  0           ['activation_6[0][0]']
#  opout2D)
#
#  conv2d_7 (Conv2D)              (None, 32, 32, 32)   9248        ['spatial_dropout2d_6[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 32, 32, 32)  128         ['conv2d_7[0][0]']
#  rmalization)
#
#  activation_7 (Activation)      (None, 32, 32, 32)   0           ['batch_normalization_7[0][0]']
#
#  spatial_dropout2d_7 (SpatialDr  (None, 32, 32, 32)  0           ['activation_7[0][0]']
#  opout2D)
#
#  conv2d_8 (Conv2D)              (None, 32, 32, 32)   1056        ['spatial_dropout2d_7[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 32, 32, 32)  128         ['conv2d_8[0][0]']
#  rmalization)
#
#  add_2 (Add)                    (None, 32, 32, 32)   0           ['batch_normalization_8[0][0]',
#                                                                   'batch_normalization_6[0][0]']
#
#  activation_8 (Activation)      (None, 32, 32, 32)   0           ['add_2[0][0]']
#
#  spatial_dropout2d_8 (SpatialDr  (None, 32, 32, 32)  0           ['activation_8[0][0]']
#  opout2D)
#
#  conv2d_9 (Conv2D)              (None, 16, 16, 64)   8256        ['spatial_dropout2d_8[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 16, 16, 64)  256         ['conv2d_9[0][0]']
#  rmalization)
#
#  activation_9 (Activation)      (None, 16, 16, 64)   0           ['batch_normalization_9[0][0]']
#
#  spatial_dropout2d_9 (SpatialDr  (None, 16, 16, 64)  0           ['activation_9[0][0]']
#  opout2D)
#
#  conv2d_10 (Conv2D)             (None, 16, 16, 64)   36928       ['spatial_dropout2d_9[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 16, 16, 64)  256         ['conv2d_10[0][0]']
#  ormalization)
#
#  activation_10 (Activation)     (None, 16, 16, 64)   0           ['batch_normalization_10[0][0]']
#
#  spatial_dropout2d_10 (SpatialD  (None, 16, 16, 64)  0           ['activation_10[0][0]']
#  ropout2D)
#
#  conv2d_11 (Conv2D)             (None, 16, 16, 64)   4160        ['spatial_dropout2d_10[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 16, 16, 64)  256         ['conv2d_11[0][0]']
#  ormalization)
#
#  add_3 (Add)                    (None, 16, 16, 64)   0           ['batch_normalization_11[0][0]',
#                                                                   'batch_normalization_9[0][0]']
#
#  activation_11 (Activation)     (None, 16, 16, 64)   0           ['add_3[0][0]']
#
#  spatial_dropout2d_11 (SpatialD  (None, 16, 16, 64)  0           ['activation_11[0][0]']
#  ropout2D)
#
#  conv2d_12 (Conv2D)             (None, 8, 8, 128)    32896       ['spatial_dropout2d_11[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 8, 8, 128)   512         ['conv2d_12[0][0]']
#  ormalization)
#
#  activation_12 (Activation)     (None, 8, 8, 128)    0           ['batch_normalization_12[0][0]']
#
#  spatial_dropout2d_12 (SpatialD  (None, 8, 8, 128)   0           ['activation_12[0][0]']
#  ropout2D)
#
#  conv2d_13 (Conv2D)             (None, 8, 8, 128)    147584      ['spatial_dropout2d_12[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 8, 8, 128)   512         ['conv2d_13[0][0]']
#  ormalization)
#
#  activation_13 (Activation)     (None, 8, 8, 128)    0           ['batch_normalization_13[0][0]']
#
#  spatial_dropout2d_13 (SpatialD  (None, 8, 8, 128)   0           ['activation_13[0][0]']
#  ropout2D)
#
#  conv2d_14 (Conv2D)             (None, 8, 8, 128)    16512       ['spatial_dropout2d_13[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 8, 8, 128)   512         ['conv2d_14[0][0]']
#  ormalization)
#
#  add_4 (Add)                    (None, 8, 8, 128)    0           ['batch_normalization_14[0][0]',
#                                                                   'batch_normalization_12[0][0]']
#
#  activation_14 (Activation)     (None, 8, 8, 128)    0           ['add_4[0][0]']
#
#  spatial_dropout2d_14 (SpatialD  (None, 8, 8, 128)   0           ['activation_14[0][0]']
#  ropout2D)
#
#  conv2d_15 (Conv2D)             (None, 8, 8, 256)    33024       ['spatial_dropout2d_14[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 8, 8, 256)   1024        ['conv2d_15[0][0]']
#  ormalization)
#
#  activation_15 (Activation)     (None, 8, 8, 256)    0           ['batch_normalization_15[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 8, 8, 256)    590080      ['activation_15[0][0]']
#
#  batch_normalization_16 (BatchN  (None, 8, 8, 256)   1024        ['conv2d_16[0][0]']
#  ormalization)
#
#  add_5 (Add)                    (None, 8, 8, 256)    0           ['batch_normalization_16[0][0]',
#                                                                   'batch_normalization_15[0][0]']
#
#  activation_16 (Activation)     (None, 8, 8, 256)    0           ['add_5[0][0]']
#
#  conv2d_transpose (Conv2DTransp  (None, 8, 8, 128)   32896       ['activation_16[0][0]']
#  ose)
#
#  batch_normalization_17 (BatchN  (None, 8, 8, 128)   512         ['conv2d_transpose[0][0]']
#  ormalization)
#
#  activation_17 (Activation)     (None, 8, 8, 128)    0           ['batch_normalization_17[0][0]']
#
#  concatenate (Concatenate)      (None, 8, 8, 256)    0           ['spatial_dropout2d_14[0][0]',
#                                                                   'activation_17[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 8, 8, 128)    295040      ['concatenate[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 8, 8, 128)   512         ['conv2d_17[0][0]']
#  ormalization)
#
#  activation_18 (Activation)     (None, 8, 8, 128)    0           ['batch_normalization_18[0][0]']
#
#  spatial_dropout2d_15 (SpatialD  (None, 8, 8, 128)   0           ['activation_18[0][0]']
#  ropout2D)
#
#  conv2d_18 (Conv2D)             (None, 8, 8, 128)    147584      ['spatial_dropout2d_15[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 8, 8, 128)   512         ['conv2d_18[0][0]']
#  ormalization)
#
#  add_6 (Add)                    (None, 8, 8, 128)    0           ['batch_normalization_19[0][0]',
#                                                                   'batch_normalization_17[0][0]']
#
#  activation_19 (Activation)     (None, 8, 8, 128)    0           ['add_6[0][0]']
#
#  spatial_dropout2d_16 (SpatialD  (None, 8, 8, 128)   0           ['activation_19[0][0]']
#  ropout2D)
#
#  conv2d_transpose_1 (Conv2DTran  (None, 16, 16, 64)  32832       ['spatial_dropout2d_16[0][0]']
#  spose)
#
#  batch_normalization_20 (BatchN  (None, 16, 16, 64)  256         ['conv2d_transpose_1[0][0]']
#  ormalization)
#
#  activation_20 (Activation)     (None, 16, 16, 64)   0           ['batch_normalization_20[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 16, 16, 128)  0           ['spatial_dropout2d_11[0][0]',
#                                                                   'activation_20[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 16, 16, 64)   73792       ['concatenate_1[0][0]']
#
#  batch_normalization_21 (BatchN  (None, 16, 16, 64)  256         ['conv2d_19[0][0]']
#  ormalization)
#
#  activation_21 (Activation)     (None, 16, 16, 64)   0           ['batch_normalization_21[0][0]']
#
#  spatial_dropout2d_17 (SpatialD  (None, 16, 16, 64)  0           ['activation_21[0][0]']
#  ropout2D)
#
#  conv2d_20 (Conv2D)             (None, 16, 16, 64)   4160        ['spatial_dropout2d_17[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 16, 16, 64)  256         ['conv2d_20[0][0]']
#  ormalization)
#
#  add_7 (Add)                    (None, 16, 16, 64)   0           ['batch_normalization_22[0][0]',
#                                                                   'batch_normalization_20[0][0]']
#
#  activation_22 (Activation)     (None, 16, 16, 64)   0           ['add_7[0][0]']
#
#  spatial_dropout2d_18 (SpatialD  (None, 16, 16, 64)  0           ['activation_22[0][0]']
#  ropout2D)
#
#  conv2d_transpose_2 (Conv2DTran  (None, 32, 32, 32)  8224        ['spatial_dropout2d_18[0][0]']
#  spose)
#
#  batch_normalization_23 (BatchN  (None, 32, 32, 32)  128         ['conv2d_transpose_2[0][0]']
#  ormalization)
#
#  activation_23 (Activation)     (None, 32, 32, 32)   0           ['batch_normalization_23[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 32, 32, 64)   0           ['spatial_dropout2d_8[0][0]',
#                                                                   'activation_23[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 32, 32, 32)   18464       ['concatenate_2[0][0]']
#
#  batch_normalization_24 (BatchN  (None, 32, 32, 32)  128         ['conv2d_21[0][0]']
#  ormalization)
#
#  activation_24 (Activation)     (None, 32, 32, 32)   0           ['batch_normalization_24[0][0]']
#
#  spatial_dropout2d_19 (SpatialD  (None, 32, 32, 32)  0           ['activation_24[0][0]']
#  ropout2D)
#
#  conv2d_22 (Conv2D)             (None, 32, 32, 32)   1056        ['spatial_dropout2d_19[0][0]']
#
#  batch_normalization_25 (BatchN  (None, 32, 32, 32)  128         ['conv2d_22[0][0]']
#  ormalization)
#
#  add_8 (Add)                    (None, 32, 32, 32)   0           ['batch_normalization_25[0][0]',
#                                                                   'batch_normalization_23[0][0]']
#
#  activation_25 (Activation)     (None, 32, 32, 32)   0           ['add_8[0][0]']
#
#  spatial_dropout2d_20 (SpatialD  (None, 32, 32, 32)  0           ['activation_25[0][0]']
#  ropout2D)
#
#  conv2d_transpose_3 (Conv2DTran  (None, 64, 64, 16)  2064        ['spatial_dropout2d_20[0][0]']
#  spose)
#
#  batch_normalization_26 (BatchN  (None, 64, 64, 16)  64          ['conv2d_transpose_3[0][0]']
#  ormalization)
#
#  activation_26 (Activation)     (None, 64, 64, 16)   0           ['batch_normalization_26[0][0]']
#
#  concatenate_3 (Concatenate)    (None, 64, 64, 32)   0           ['spatial_dropout2d_5[0][0]',
#                                                                   'activation_26[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 64, 64, 16)   4624        ['concatenate_3[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 64, 64, 16)  64          ['conv2d_23[0][0]']
#  ormalization)
#
#  activation_27 (Activation)     (None, 64, 64, 16)   0           ['batch_normalization_27[0][0]']
#
#  spatial_dropout2d_21 (SpatialD  (None, 64, 64, 16)  0           ['activation_27[0][0]']
#  ropout2D)
#
#  conv2d_24 (Conv2D)             (None, 64, 64, 16)   272         ['spatial_dropout2d_21[0][0]']
#
#  batch_normalization_28 (BatchN  (None, 64, 64, 16)  64          ['conv2d_24[0][0]']
#  ormalization)
#
#  add_9 (Add)                    (None, 64, 64, 16)   0           ['batch_normalization_28[0][0]',
#                                                                   'batch_normalization_26[0][0]']
#
#  activation_28 (Activation)     (None, 64, 64, 16)   0           ['add_9[0][0]']
#
#  spatial_dropout2d_22 (SpatialD  (None, 64, 64, 16)  0           ['activation_28[0][0]']
#  ropout2D)
#
#  conv2d_transpose_4 (Conv2DTran  (None, 128, 128, 8)  520        ['spatial_dropout2d_22[0][0]']
#  spose)
#
#  batch_normalization_29 (BatchN  (None, 128, 128, 8)  32         ['conv2d_transpose_4[0][0]']
#  ormalization)
#
#  activation_29 (Activation)     (None, 128, 128, 8)  0           ['batch_normalization_29[0][0]']
#
#  concatenate_4 (Concatenate)    (None, 128, 128, 16  0           ['spatial_dropout2d_2[0][0]',
#                                 )                                 'activation_29[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 128, 128, 8)  1160        ['concatenate_4[0][0]']
#
#  batch_normalization_30 (BatchN  (None, 128, 128, 8)  32         ['conv2d_25[0][0]']
#  ormalization)
#
#  activation_30 (Activation)     (None, 128, 128, 8)  0           ['batch_normalization_30[0][0]']
#
#  spatial_dropout2d_23 (SpatialD  (None, 128, 128, 8)  0          ['activation_30[0][0]']
#  ropout2D)
#
#  conv2d_26 (Conv2D)             (None, 128, 128, 8)  72          ['spatial_dropout2d_23[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 128, 128, 8)  32         ['conv2d_26[0][0]']
#  ormalization)
#
#  add_10 (Add)                   (None, 128, 128, 8)  0           ['batch_normalization_31[0][0]',
#                                                                   'batch_normalization_29[0][0]']
#
#  activation_31 (Activation)     (None, 128, 128, 8)  0           ['add_10[0][0]']
#
#  spatial_dropout2d_24 (SpatialD  (None, 128, 128, 8)  0          ['activation_31[0][0]']
#  ropout2D)
#
#  conv2d_27 (Conv2D)             (None, 128, 128, 1)  9           ['spatial_dropout2d_24[0][0]']
#
# ==================================================================================================
# Total params: 1,516,385
# Trainable params: 1,512,385
# Non-trainable params: 4,000
# __________________________________________________________________________________________________
# Epoch 1/50
# 62/62 [==============================] - 13s 77ms/step - loss: 343.0910 - DSC: 0.3455 - val_loss: 309.8437 - val_DSC: 0.4154 - lr: 1.0000e-04
# Epoch 2/50
# 62/62 [==============================] - 4s 61ms/step - loss: 281.9040 - DSC: 0.4019 - val_loss: 255.0444 - val_DSC: 0.4154 - lr: 1.0000e-04
# Epoch 3/50
