# %% [markdown]
# # U-Net architecture definition

# %% [markdown]
# We have to define the structure of our FCNN. Let's import the packages. NB: we are not importing Keras directly but we import keras through tensorflow! We do this to be sure that we are using always the same packages.

# %%
import numpy as np
import os
from tensorflow.keras import backend as K
from tensorflow.keras import regularizers, initializers
from tensorflow.keras.activations import softmax
from tensorflow.keras.layers import Input, BatchNormalization, SpatialDropout2D, Conv2D, Conv2DTranspose, Concatenate, Activation, Add
from tensorflow.keras.models import Sequential, Model
import tensorflow as tf

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
os.environ["CUDA_VISIBLE_DEVICES"]="0"

# %% [markdown]
# **Regularizer**: we can define a penality on layer parameters or layer activity during optimization. In the following, we will use kernel_regularizer. This means we are applying a penality on the kernel layers.
#
# **Initializer**: when we begin the training of a NN we can set the initial weights distribution.
# In this exercise, both regularizers and initializers are declared inside the convolutional layer.
#
# **Input**: Input is a function that is used to instantiate a keras tensor. A Keras tensor is a symbolic tensor-like object, which we augment with certain attributes that allow us to build a Keras model just by knowing the inputs and outputs of the model. For example attributes are: input shape, batch size... You can find the full attributes list [here](https://keras.io/api/layers/core_layers/input/).
#
# **BatchNormalization**: [Batch normalization](https://arxiv.org/abs/1502.03167) is a way to regularize the model by reducing the internal covariate shift. This layer normalizes its output using the mean and standard deviation of the current batch of inputs and maintain the mean close to zero and the standard deviation close to 1.
#
# **SpatialDropout2D**: Dropout is a method used to regularize the NN. It randomly sets input units to 0 with a frequency of rate at each step during training time, which helps prevent overfitting. [SpatialDropout2D](https://arxiv.org/abs/1411.4280) is instead applied on an entire feature map. This helps the network to learn independent feature maps.
#
# **Conv2D**: [2D Convolution Layer](https://keras.io/api/layers/convolution_layers/convolution2d/). In the link you can find the parameters we can set in the convolutional layers.
#
# **Conv2DTranspose**: as discussed in the lesson of this morning, the U-Net has a U structure: in the first left part (strided) convolution, pooling and activations are used to compress the information while in the last right part the compressed information is upsampled to the input size. We can mainly perform upsampling in two ways:
# 1) A simple parameters-free upsampling:
#
# <center><img src="../images/upsampling.png" alt="fishy" class="bg-primary mb-1" width="500px"/></center>
#
#
# 2) We can use instead Transpose Convolution with the advantage that the network will have kernels that can learn the better way to upsample the information: this is how it works.
#
# <center><img src="../images/deconvolution.png" alt="fishy" class="bg-primary mb-1" width="700px"></center>
#
# **Concatenate**: it simply concatenates two tensors. In this case, we are using the concatenate layer to create the skip connections between the left and the right part of the U-Net.
#
# **Activation**: the activation layer is the one used to define non-linear function in order to activate the kernel. In this case we are going to use a simple ReLU.
#
# **Add**: the add layer simply sums two input tensors. In this architecture it is used to compute a residual connection inside each block of both compression and decompression path.

# %% [markdown]
# # Compression path definition
# In this part of the code, we define the structure of each block of the compression path.

# %%
def unet_layer_left(previous_layer, n_filters, ker_size_1, strides_1, ker_size_2, strides_2, ker_size_3, strides_3, reg):
    '''Definition of layers of the left part of the u-net. 
    Parameters
    ------------------
    previous_layer : input layer for this block;
    n_filters : number of filters of all the 3D convolutional layers;
    ker_size_1 : kernel dimension of the first conv3D layer of this block;
    strides_1 : strides size to be used for the convolution of the first Conv3D layer;
    ker_size_2/3 : kernel dimension of the second/third Conv3D layers;
    strides_2/3 : strides size to be used for the convolution of the second/third Conv3D layer;
    '''
    layer_L=Conv2D(filters=n_filters,kernel_size=ker_size_1,strides=strides_1,kernel_regularizer=regularizers.l2(reg), kernel_initializer='random_normal')(previous_layer)
    layer_L=BatchNormalization(axis=-1)(layer_L)  
    layer_L_shortcut=layer_L
    layer_L=Activation('relu')(layer_L)
    layer_L=SpatialDropout2D(0.2)(layer_L)
    layer_L=Conv2D(filters=n_filters,kernel_size=ker_size_2,strides=strides_2,padding='same',kernel_regularizer=regularizers.l2(reg), kernel_initializer='random_normal')(layer_L)
    layer_L=BatchNormalization(axis=-1)(layer_L)  
    layer_L=Activation('relu')(layer_L)
    layer_L=SpatialDropout2D(0.2)(layer_L)
    layer_L=Conv2D(filters=n_filters,kernel_size=ker_size_3,strides=strides_3,padding='same',kernel_regularizer=regularizers.l2(reg), kernel_initializer='random_normal')(layer_L)
    layer_L=BatchNormalization(axis=-1)(layer_L)  
    layer_L=Add()([layer_L,layer_L_shortcut])
    layer_L=Activation('relu')(layer_L)
    layer_L=SpatialDropout2D(0.2)(layer_L)
    return layer_L

# %% [markdown]
# **Questions**:
# 1) How many convolution layers are there?
# 2) Why we stored the variable 'layer_L' in 'layer_L_shorcut'?
# 3) What is the padding? What does 'same' mean?

# %% [markdown]
# # Bottleneck block
#
# The following cell contains the code for the bottom block of the U-Net

# %%
def unet_layer_bottleneck(previous_layer, n_filters, ker_size_1, strides_1, ker_size_2, strides_2, reg):
    '''Definition of the last layer of the network. 
    Parameters
    ------------------
    previous_layer : input layer for this block;
    n_filters : number of filters of all the 3D convolutional layers;
    ker_size_1 : kernel dimension of the first conv3D layer of this block;
    strides_1 : strides size to be used for the convolution of the first Conv3D layer;
    ker_size_2 : kernel dimension of the second Conv3D layers;
    strides_2 : strides size to be used for the convolution of the second Conv3D layer;
    '''
    layer_L=Conv2D(filters=n_filters,kernel_size=ker_size_1,strides=strides_1,kernel_regularizer=regularizers.l2(reg), kernel_initializer='random_normal')(previous_layer)
    layer_L=BatchNormalization(axis=-1)(layer_L)  
    layer_L_shortcut=layer_L 
    layer_L=Activation('relu')(layer_L)
    layer_L=Conv2D(filters=n_filters,kernel_size=ker_size_2,strides=strides_2,padding='same',kernel_regularizer=regularizers.l2(reg), kernel_initializer='random_normal')(layer_L)
    layer_L=BatchNormalization(axis=-1)(layer_L)    
    layer_L=Add()([layer_L,layer_L_shortcut])
    layer_L=Activation('relu')(layer_L)
    return layer_L

# %% [markdown]
# # Decompression path definition
# Here, we define the decompression path. As you can see each block of the decompression path takes as input the corresponding left layer in order to build the skip connections.

# %%
def unet_layer_right(previous_layer, layer_left, n_filters, ker_size_1, strides_1, output_pad, ker_size_2, strides_2, ker_size_3, strides_3, reg):
    '''Definition of layers of the right part of the u-net. 
    Parameters
    ------------------
    previous_layer : input layer for this block;
    layer_left : output layer of the left part at the same depth;
    n_filters : int, number of filters of all the 3D convolutional layers;
    ker_size_1 : int, kernel dimension of the first conv3D layer of this block;
    strides_1 : int, strides size to be used for the convolution of the first Conv3D layer;
    output_pad : tuple, padding for the output;
    ker_size_2/3 : int, kernel dimension of the second/third Conv3D layers;
    strides_2/3 : int, strides size to be used for the convolution of the second/third Conv3D layer;
    '''
    layer_R=Conv2DTranspose(filters=n_filters,kernel_size=ker_size_1,strides=strides_1,output_padding=output_pad,kernel_regularizer=regularizers.l2(reg), kernel_initializer='random_normal')(previous_layer)
    layer_R=BatchNormalization(axis=-1)(layer_R)
    layer_R_shortcut=layer_R
    layer_R=Activation('relu')(layer_R)
    merge=Concatenate(axis=-1)([layer_left,layer_R])
    layer_R=Conv2D(filters=n_filters,kernel_size=ker_size_2,strides=strides_2,padding='same',kernel_regularizer=regularizers.l2(reg), kernel_initializer='random_normal')(merge)
    layer_R=BatchNormalization(axis=-1)(layer_R)  
    layer_R=Activation('relu')(layer_R)
    layer_R=SpatialDropout2D(0.2)(layer_R)
    layer_R=Conv2D(filters=n_filters,kernel_size=ker_size_3,strides=strides_3,padding='same',kernel_regularizer=regularizers.l2(reg), kernel_initializer='random_normal')(layer_R)
    layer_R=BatchNormalization(axis=-1)(layer_R)  
    layer_R=Add()([layer_R,layer_R_shortcut])
    layer_R=Activation('relu')(layer_R)
    layer_R=SpatialDropout2D(0.2)(layer_R)

    return layer_R

# %% [markdown]
# **Questions**
# 1) Why is axis set to -1 in the concatenate layer? What does it mean?
# 2) What condition(s) have to be satisfied in order to perform the concatenation?
#
# **Very hard question**
# 3) If the input image size is not a power of 2, what parameters we should check in the convolutional layers in order to not have errors?

# %% [markdown]
# # U-NET architecture
# Here we put together all the pieces we wrote above in order to write the full U-Net architecture.
# The structure is: first we put the compression path (L -> Left), then the bottleneck block and lastly the decompression path (R -> Right).

# %%
def U_net(input_size):
    '''This function builds the network without compiling it.
    Parameters
    ---------------------
    input_size : tuple , size of the input
    reg : float , regularization parameters (L2)
    '''
    inputs=Input(shape=(input_size)) ## 
    Level_1_L = unet_layer_left(inputs, n_filters=16, ker_size_1=1,strides_1=1,ker_size_2=3, strides_2=1, ker_size_3=1, strides_3=1, reg = 0.1)
    Level_2_L = unet_layer_left(Level_1_L, n_filters=32,ker_size_1=2, strides_1=2, ker_size_2=3,strides_2=1, ker_size_3=1, strides_3=1, reg = 0.1)
    Level_3_L = unet_layer_left(Level_2_L, n_filters=64, ker_size_1=2, strides_1=2, ker_size_2=3, strides_2=1, ker_size_3=1, strides_3=1, reg = 0.1)
    Level_4_L = unet_layer_left(Level_3_L, n_filters=128, ker_size_1=2, strides_1=2, ker_size_2=3, strides_2=1, ker_size_3=1, strides_3=1, reg = 0.1)
    Level_5_L = unet_layer_left(Level_4_L, n_filters=256, ker_size_1=2, strides_1=2, ker_size_2=3, strides_2=1, ker_size_3=1, strides_3=1, reg = 0.1)
    Level_6_L = unet_layer_bottleneck(Level_5_L, n_filters= 512, ker_size_1=1, strides_1=1, ker_size_2=3, strides_2=1, reg=0.1)
    Level_5_R = unet_layer_right(Level_6_L, Level_5_L, n_filters=256, ker_size_1=1, strides_1=1, output_pad=None, ker_size_2=3, strides_2=1, ker_size_3=3, strides_3=1, reg=0.1)
    Level_4_R = unet_layer_right(Level_5_R, Level_4_L, n_filters=128, ker_size_1=2, strides_1=2, output_pad=None,ker_size_2=3, strides_2=1, ker_size_3=1, strides_3=1, reg = 0.1)
    Level_3_R = unet_layer_right(Level_4_R, Level_3_L, n_filters=64, ker_size_1=2, strides_1=2, output_pad=None, ker_size_2=3, strides_2=1, ker_size_3=1, strides_3=1, reg = 0.1)
    Level_2_R = unet_layer_right(Level_3_R, Level_2_L, n_filters=32, ker_size_1=2, strides_1=2, output_pad=None, ker_size_2=3, strides_2=1, ker_size_3=1, strides_3=1, reg = 0.1)
    Level_1_R = unet_layer_right(Level_2_R, Level_1_L, n_filters=16, ker_size_1=2, strides_1=2, output_pad=None, ker_size_2=3, strides_2=1, ker_size_3=1, strides_3=1, reg = 0.1)
    output=Conv2D(filters=1,kernel_size=1,strides=1, activation = 'sigmoid', kernel_regularizer=regularizers.l2(0.1))(Level_1_R)
    model=Model(inputs=inputs,outputs=output)
    return model

# %% [markdown]
# # TEST
# Let's test the architecture:
# - we generate a set of mock data
# - we train the U-Net

# %%
#mock data
test_data = np.zeros((2,256,256,1))
test_label = np.zeros((2,256,256,1))

# %%
# we call the U-Net function
model = U_net((256,256,1))

# %%
met = tf.keras.metrics.MeanIoU(num_classes=2) # we choose a built-in metric in keras that is Intersection Over Union
model.compile(optimizer="rmsprop", loss="sparse_categorical_crossentropy") # we define an optimizer and a loss function
model.summary() # print the model
history=model.fit(test_data, test_label, epochs=3,verbose=1) # here we fit the model
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 256, 256, 1  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 256, 256, 16  32          ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 256, 256, 16  64         ['conv2d[0][0]']
#  alization)                     )
#
#  activation (Activation)        (None, 256, 256, 16  0           ['batch_normalization[0][0]']
#                                 )
#
#  spatial_dropout2d (SpatialDrop  (None, 256, 256, 16  0          ['activation[0][0]']
#  out2D)                         )
#
#  conv2d_1 (Conv2D)              (None, 256, 256, 16  2320        ['spatial_dropout2d[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 256, 256, 16  64         ['conv2d_1[0][0]']
#  rmalization)                   )
#
#  activation_1 (Activation)      (None, 256, 256, 16  0           ['batch_normalization_1[0][0]']
#                                 )
#
#  spatial_dropout2d_1 (SpatialDr  (None, 256, 256, 16  0          ['activation_1[0][0]']
#  opout2D)                       )
#
#  conv2d_2 (Conv2D)              (None, 256, 256, 16  272         ['spatial_dropout2d_1[0][0]']
#                                 )
#
#  batch_normalization_2 (BatchNo  (None, 256, 256, 16  64         ['conv2d_2[0][0]']
#  rmalization)                   )
#
#  add (Add)                      (None, 256, 256, 16  0           ['batch_normalization_2[0][0]',
#                                 )                                 'batch_normalization[0][0]']
#
#  activation_2 (Activation)      (None, 256, 256, 16  0           ['add[0][0]']
#                                 )
#
#  spatial_dropout2d_2 (SpatialDr  (None, 256, 256, 16  0          ['activation_2[0][0]']
#  opout2D)                       )
#
#  conv2d_3 (Conv2D)              (None, 128, 128, 32  2080        ['spatial_dropout2d_2[0][0]']
#                                 )
#
#  batch_normalization_3 (BatchNo  (None, 128, 128, 32  128        ['conv2d_3[0][0]']
#  rmalization)                   )
#
#  activation_3 (Activation)      (None, 128, 128, 32  0           ['batch_normalization_3[0][0]']
#                                 )
#
#  spatial_dropout2d_3 (SpatialDr  (None, 128, 128, 32  0          ['activation_3[0][0]']
#  opout2D)                       )
#
#  conv2d_4 (Conv2D)              (None, 128, 128, 32  9248        ['spatial_dropout2d_3[0][0]']
#                                 )
#
#  batch_normalization_4 (BatchNo  (None, 128, 128, 32  128        ['conv2d_4[0][0]']
#  rmalization)                   )
#
#  activation_4 (Activation)      (None, 128, 128, 32  0           ['batch_normalization_4[0][0]']
#                                 )
#
#  spatial_dropout2d_4 (SpatialDr  (None, 128, 128, 32  0          ['activation_4[0][0]']
#  opout2D)                       )
#
#  conv2d_5 (Conv2D)              (None, 128, 128, 32  1056        ['spatial_dropout2d_4[0][0]']
#                                 )
#
#  batch_normalization_5 (BatchNo  (None, 128, 128, 32  128        ['conv2d_5[0][0]']
#  rmalization)                   )
#
#  add_1 (Add)                    (None, 128, 128, 32  0           ['batch_normalization_5[0][0]',
#                                 )                                 'batch_normalization_3[0][0]']
#
#  activation_5 (Activation)      (None, 128, 128, 32  0           ['add_1[0][0]']
#                                 )
#
#  spatial_dropout2d_5 (SpatialDr  (None, 128, 128, 32  0          ['activation_5[0][0]']
#  opout2D)                       )
#
#  conv2d_6 (Conv2D)              (None, 64, 64, 64)   8256        ['spatial_dropout2d_5[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 64, 64, 64)  256         ['conv2d_6[0][0]']
#  rmalization)
#
#  activation_6 (Activation)      (None, 64, 64, 64)   0           ['batch_normalization_6[0][0]']
#
#  spatial_dropout2d_6 (SpatialDr  (None, 64, 64, 64)  0           ['activation_6[0][0]']
#  opout2D)
#
#  conv2d_7 (Conv2D)              (None, 64, 64, 64)   36928       ['spatial_dropout2d_6[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 64, 64, 64)  256         ['conv2d_7[0][0]']
#  rmalization)
#
#  activation_7 (Activation)      (None, 64, 64, 64)   0           ['batch_normalization_7[0][0]']
#
#  spatial_dropout2d_7 (SpatialDr  (None, 64, 64, 64)  0           ['activation_7[0][0]']
#  opout2D)
#
#  conv2d_8 (Conv2D)              (None, 64, 64, 64)   4160        ['spatial_dropout2d_7[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 64, 64, 64)  256         ['conv2d_8[0][0]']
#  rmalization)
#
#  add_2 (Add)                    (None, 64, 64, 64)   0           ['batch_normalization_8[0][0]',
#                                                                   'batch_normalization_6[0][0]']
#
#  activation_8 (Activation)      (None, 64, 64, 64)   0           ['add_2[0][0]']
#
#  spatial_dropout2d_8 (SpatialDr  (None, 64, 64, 64)  0           ['activation_8[0][0]']
#  opout2D)
#
#  conv2d_9 (Conv2D)              (None, 32, 32, 128)  32896       ['spatial_dropout2d_8[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 32, 32, 128)  512        ['conv2d_9[0][0]']
#  rmalization)
#
#  activation_9 (Activation)      (None, 32, 32, 128)  0           ['batch_normalization_9[0][0]']
#
#  spatial_dropout2d_9 (SpatialDr  (None, 32, 32, 128)  0          ['activation_9[0][0]']
#  opout2D)
#
#  conv2d_10 (Conv2D)             (None, 32, 32, 128)  147584      ['spatial_dropout2d_9[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 32, 32, 128)  512        ['conv2d_10[0][0]']
#  ormalization)
#
#  activation_10 (Activation)     (None, 32, 32, 128)  0           ['batch_normalization_10[0][0]']
#
#  spatial_dropout2d_10 (SpatialD  (None, 32, 32, 128)  0          ['activation_10[0][0]']
#  ropout2D)
#
#  conv2d_11 (Conv2D)             (None, 32, 32, 128)  16512       ['spatial_dropout2d_10[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 32, 32, 128)  512        ['conv2d_11[0][0]']
#  ormalization)
#
#  add_3 (Add)                    (None, 32, 32, 128)  0           ['batch_normalization_11[0][0]',
#                                                                   'batch_normalization_9[0][0]']
#
#  activation_11 (Activation)     (None, 32, 32, 128)  0           ['add_3[0][0]']
#
#  spatial_dropout2d_11 (SpatialD  (None, 32, 32, 128)  0          ['activation_11[0][0]']
#  ropout2D)
#
#  conv2d_12 (Conv2D)             (None, 16, 16, 256)  131328      ['spatial_dropout2d_11[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 16, 16, 256)  1024       ['conv2d_12[0][0]']
#  ormalization)
#
#  activation_12 (Activation)     (None, 16, 16, 256)  0           ['batch_normalization_12[0][0]']
#
#  spatial_dropout2d_12 (SpatialD  (None, 16, 16, 256)  0          ['activation_12[0][0]']
#  ropout2D)
#
#  conv2d_13 (Conv2D)             (None, 16, 16, 256)  590080      ['spatial_dropout2d_12[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 16, 16, 256)  1024       ['conv2d_13[0][0]']
#  ormalization)
#
#  activation_13 (Activation)     (None, 16, 16, 256)  0           ['batch_normalization_13[0][0]']
#
#  spatial_dropout2d_13 (SpatialD  (None, 16, 16, 256)  0          ['activation_13[0][0]']
#  ropout2D)
#
#  conv2d_14 (Conv2D)             (None, 16, 16, 256)  65792       ['spatial_dropout2d_13[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 16, 16, 256)  1024       ['conv2d_14[0][0]']
#  ormalization)
#
#  add_4 (Add)                    (None, 16, 16, 256)  0           ['batch_normalization_14[0][0]',
#                                                                   'batch_normalization_12[0][0]']
#
#  activation_14 (Activation)     (None, 16, 16, 256)  0           ['add_4[0][0]']
#
#  spatial_dropout2d_14 (SpatialD  (None, 16, 16, 256)  0          ['activation_14[0][0]']
#  ropout2D)
#
#  conv2d_15 (Conv2D)             (None, 16, 16, 512)  131584      ['spatial_dropout2d_14[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 16, 16, 512)  2048       ['conv2d_15[0][0]']
#  ormalization)
#
#  activation_15 (Activation)     (None, 16, 16, 512)  0           ['batch_normalization_15[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 16, 16, 512)  2359808     ['activation_15[0][0]']
#
#  batch_normalization_16 (BatchN  (None, 16, 16, 512)  2048       ['conv2d_16[0][0]']
#  ormalization)
#
#  add_5 (Add)                    (None, 16, 16, 512)  0           ['batch_normalization_16[0][0]',
#                                                                   'batch_normalization_15[0][0]']
#
#  activation_16 (Activation)     (None, 16, 16, 512)  0           ['add_5[0][0]']
#
#  conv2d_transpose (Conv2DTransp  (None, 16, 16, 256)  131328     ['activation_16[0][0]']
#  ose)
#
#  batch_normalization_17 (BatchN  (None, 16, 16, 256)  1024       ['conv2d_transpose[0][0]']
#  ormalization)
#
#  activation_17 (Activation)     (None, 16, 16, 256)  0           ['batch_normalization_17[0][0]']
#
#  concatenate (Concatenate)      (None, 16, 16, 512)  0           ['spatial_dropout2d_14[0][0]',
#                                                                   'activation_17[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 16, 16, 256)  1179904     ['concatenate[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 16, 16, 256)  1024       ['conv2d_17[0][0]']
#  ormalization)
#
#  activation_18 (Activation)     (None, 16, 16, 256)  0           ['batch_normalization_18[0][0]']
#
#  spatial_dropout2d_15 (SpatialD  (None, 16, 16, 256)  0          ['activation_18[0][0]']
#  ropout2D)
#
#  conv2d_18 (Conv2D)             (None, 16, 16, 256)  590080      ['spatial_dropout2d_15[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 16, 16, 256)  1024       ['conv2d_18[0][0]']
#  ormalization)
#
#  add_6 (Add)                    (None, 16, 16, 256)  0           ['batch_normalization_19[0][0]',
#                                                                   'batch_normalization_17[0][0]']
#
#  activation_19 (Activation)     (None, 16, 16, 256)  0           ['add_6[0][0]']
#
#  spatial_dropout2d_16 (SpatialD  (None, 16, 16, 256)  0          ['activation_19[0][0]']
#  ropout2D)
#
#  conv2d_transpose_1 (Conv2DTran  (None, 32, 32, 128)  131200     ['spatial_dropout2d_16[0][0]']
#  spose)
#
#  batch_normalization_20 (BatchN  (None, 32, 32, 128)  512        ['conv2d_transpose_1[0][0]']
#  ormalization)
#
#  activation_20 (Activation)     (None, 32, 32, 128)  0           ['batch_normalization_20[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 32, 32, 256)  0           ['spatial_dropout2d_11[0][0]',
#                                                                   'activation_20[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 32, 32, 128)  295040      ['concatenate_1[0][0]']
#
#  batch_normalization_21 (BatchN  (None, 32, 32, 128)  512        ['conv2d_19[0][0]']
#  ormalization)
#
#  activation_21 (Activation)     (None, 32, 32, 128)  0           ['batch_normalization_21[0][0]']
#
#  spatial_dropout2d_17 (SpatialD  (None, 32, 32, 128)  0          ['activation_21[0][0]']
#  ropout2D)
#
#  conv2d_20 (Conv2D)             (None, 32, 32, 128)  16512       ['spatial_dropout2d_17[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 32, 32, 128)  512        ['conv2d_20[0][0]']
#  ormalization)
#
#  add_7 (Add)                    (None, 32, 32, 128)  0           ['batch_normalization_22[0][0]',
#                                                                   'batch_normalization_20[0][0]']
#
#  activation_22 (Activation)     (None, 32, 32, 128)  0           ['add_7[0][0]']
#
#  spatial_dropout2d_18 (SpatialD  (None, 32, 32, 128)  0          ['activation_22[0][0]']
#  ropout2D)
#
#  conv2d_transpose_2 (Conv2DTran  (None, 64, 64, 64)  32832       ['spatial_dropout2d_18[0][0]']
#  spose)
#
#  batch_normalization_23 (BatchN  (None, 64, 64, 64)  256         ['conv2d_transpose_2[0][0]']
#  ormalization)
#
#  activation_23 (Activation)     (None, 64, 64, 64)   0           ['batch_normalization_23[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 64, 64, 128)  0           ['spatial_dropout2d_8[0][0]',
#                                                                   'activation_23[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 64, 64, 64)   73792       ['concatenate_2[0][0]']
#
#  batch_normalization_24 (BatchN  (None, 64, 64, 64)  256         ['conv2d_21[0][0]']
#  ormalization)
#
#  activation_24 (Activation)     (None, 64, 64, 64)   0           ['batch_normalization_24[0][0]']
#
#  spatial_dropout2d_19 (SpatialD  (None, 64, 64, 64)  0           ['activation_24[0][0]']
#  ropout2D)
#
#  conv2d_22 (Conv2D)             (None, 64, 64, 64)   4160        ['spatial_dropout2d_19[0][0]']
#
#  batch_normalization_25 (BatchN  (None, 64, 64, 64)  256         ['conv2d_22[0][0]']
#  ormalization)
#
#  add_8 (Add)                    (None, 64, 64, 64)   0           ['batch_normalization_25[0][0]',
#                                                                   'batch_normalization_23[0][0]']
#
#  activation_25 (Activation)     (None, 64, 64, 64)   0           ['add_8[0][0]']
#
#  spatial_dropout2d_20 (SpatialD  (None, 64, 64, 64)  0           ['activation_25[0][0]']
#  ropout2D)
#
#  conv2d_transpose_3 (Conv2DTran  (None, 128, 128, 32  8224       ['spatial_dropout2d_20[0][0]']
#  spose)                         )
#
#  batch_normalization_26 (BatchN  (None, 128, 128, 32  128        ['conv2d_transpose_3[0][0]']
#  ormalization)                  )
#
#  activation_26 (Activation)     (None, 128, 128, 32  0           ['batch_normalization_26[0][0]']
#                                 )
#
#  concatenate_3 (Concatenate)    (None, 128, 128, 64  0           ['spatial_dropout2d_5[0][0]',
#                                 )                                 'activation_26[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 128, 128, 32  18464       ['concatenate_3[0][0]']
#                                 )
#
#  batch_normalization_27 (BatchN  (None, 128, 128, 32  128        ['conv2d_23[0][0]']
#  ormalization)                  )
#
#  activation_27 (Activation)     (None, 128, 128, 32  0           ['batch_normalization_27[0][0]']
#                                 )
#
#  spatial_dropout2d_21 (SpatialD  (None, 128, 128, 32  0          ['activation_27[0][0]']
#  ropout2D)                      )
#
#  conv2d_24 (Conv2D)             (None, 128, 128, 32  1056        ['spatial_dropout2d_21[0][0]']
#                                 )
#
#  batch_normalization_28 (BatchN  (None, 128, 128, 32  128        ['conv2d_24[0][0]']
#  ormalization)                  )
#
#  add_9 (Add)                    (None, 128, 128, 32  0           ['batch_normalization_28[0][0]',
#                                 )                                 'batch_normalization_26[0][0]']
#
#  activation_28 (Activation)     (None, 128, 128, 32  0           ['add_9[0][0]']
#                                 )
#
#  spatial_dropout2d_22 (SpatialD  (None, 128, 128, 32  0          ['activation_28[0][0]']
#  ropout2D)                      )
#
#  conv2d_transpose_4 (Conv2DTran  (None, 256, 256, 16  2064       ['spatial_dropout2d_22[0][0]']
#  spose)                         )
#
#  batch_normalization_29 (BatchN  (None, 256, 256, 16  64         ['conv2d_transpose_4[0][0]']
#  ormalization)                  )
#
#  activation_29 (Activation)     (None, 256, 256, 16  0           ['batch_normalization_29[0][0]']
#                                 )
#
#  concatenate_4 (Concatenate)    (None, 256, 256, 32  0           ['spatial_dropout2d_2[0][0]',
#                                 )                                 'activation_29[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 256, 256, 16  4624        ['concatenate_4[0][0]']
#                                 )
#
#  batch_normalization_30 (BatchN  (None, 256, 256, 16  64         ['conv2d_25[0][0]']
#  ormalization)                  )
#
#  activation_30 (Activation)     (None, 256, 256, 16  0           ['batch_normalization_30[0][0]']
#                                 )
#
#  spatial_dropout2d_23 (SpatialD  (None, 256, 256, 16  0          ['activation_30[0][0]']
#  ropout2D)                      )
#
#  conv2d_26 (Conv2D)             (None, 256, 256, 16  272         ['spatial_dropout2d_23[0][0]']
#                                 )
#
#  batch_normalization_31 (BatchN  (None, 256, 256, 16  64         ['conv2d_26[0][0]']
#  ormalization)                  )
#
#  add_10 (Add)                   (None, 256, 256, 16  0           ['batch_normalization_31[0][0]',
#                                 )                                 'batch_normalization_29[0][0]']
#
#  activation_31 (Activation)     (None, 256, 256, 16  0           ['add_10[0][0]']
#                                 )
#
#  spatial_dropout2d_24 (SpatialD  (None, 256, 256, 16  0          ['activation_31[0][0]']
#  ropout2D)                      )
#
#  conv2d_27 (Conv2D)             (None, 256, 256, 1)  17          ['spatial_dropout2d_24[0][0]']
#
# ==================================================================================================
# Total params: 6,045,505
# Trainable params: 6,037,505
# Non-trainable params: 8,000
# __________________________________________________________________________________________________
# Epoch 1/3
# 1/1 [==============================] - 11s 11s/step - loss: 1507.2627
# Epoch 2/3
# 1/1 [==============================] - 0s 44ms/step - loss: 1361.2285
# Epoch 3/3
# 1/1 [==============================] - 0s 42ms/step - loss: 1265.5662

# %% [markdown]
# **What if the in input size is not a power of 2?**

# %%
test_data = np.zeros((2,200,200,1))
test_label = np.zeros((2,200,200,1))

# %%
model = U_net((200,200,1))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_1450/1145076899.py in <module>
# ----> 1 model = U_net((200,200,1))
#
# /tmp/ipykernel_1450/1324502193.py in U_net(input_size)
#      14     Level_6_L = unet_layer_bottleneck(Level_5_L, n_filters= 512, ker_size_1=1, strides_1=1, ker_size_2=3, strides_2=1, reg=0.1)
#      15     Level_5_R = unet_layer_right(Level_6_L, Level_5_L, n_filters=256, ker_size_1=1, strides_1=1, output_pad=None, ker_size_2=3, strides_2=1, ker_size_3=3, strides_3=1, reg=0.1)
# ---> 16     Level_4_R = unet_layer_right(Level_5_R, Level_4_L, n_filters=128, ker_size_1=2, strides_1=2, output_pad=None,ker_size_2=3, strides_2=1, ker_size_3=1, strides_3=1, reg = 0.1)
#      17     Level_3_R = unet_layer_right(Level_4_R, Level_3_L, n_filters=64, ker_size_1=2, strides_1=2, output_pad=None, ker_size_2=3, strides_2=1, ker_size_3=1, strides_3=1, reg = 0.1)
#      18     Level_2_R = unet_layer_right(Level_3_R, Level_2_L, n_filters=32, ker_size_1=2, strides_1=2, output_pad=None, ker_size_2=3, strides_2=1, ker_size_3=1, strides_3=1, reg = 0.1)
#
# /tmp/ipykernel_1450/1138421946.py in unet_layer_right(previous_layer, layer_left, n_filters, ker_size_1, strides_1, output_pad, ker_size_2, strides_2, ker_size_3, strides_3, reg)
#      16     layer_R_shortcut=layer_R
#      17     layer_R=Activation('relu')(layer_R)
# ---> 18     merge=Concatenate(axis=-1)([layer_left,layer_R])
#      19     layer_R=Conv2D(filters=n_filters,kernel_size=ker_size_2,strides=strides_2,padding='same',kernel_regularizer=regularizers.l2(reg), kernel_initializer='random_normal')(merge)
#      20     layer_R=BatchNormalization(axis=-1)(layer_R)
#
# /usr/local/lib/python3.8/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67       raise e.with_traceback(filtered_tb) from None
#      68     finally:
#      69       del filtered_tb
#
# /usr/local/lib/python3.8/dist-packages/keras/layers/merge.py in build(self, input_shape)
#     523             shape[axis] for shape in shape_set if shape[axis] is not None)
#     524         if len(unique_dims) > 1:
# --> 525           raise ValueError(err_msg)
#     526
#     527   def _merge_function(self, inputs):
#
# ValueError: A `Concatenate` layer requires inputs with matching shapes except for the concatenation axis. Received: input_shape=[(None, 25, 25, 128), (None, 24, 24, 128)]

# %% [markdown]
# What does this error means? Why the input shapes of the layer_4_L have different values? What should we do?

# %%
def U_net_adj(input_size):
    '''This function builds the network without compiling it.
    Parameters
    ---------------------
    input_size : tuple , size of the input
    reg : float , regularization parameters (L2)
    '''
    inputs=Input(shape=(input_size)) ## 
    Level_1_L = unet_layer_left(inputs, n_filters=16, ker_size_1=1,strides_1=1,ker_size_2=3, strides_2=1, ker_size_3=1, strides_3=1, reg = 0.1)
    Level_2_L = unet_layer_left(Level_1_L, n_filters=32,ker_size_1=2, strides_1=2, ker_size_2=3,strides_2=1, ker_size_3=1, strides_3=1, reg = 0.1)
    Level_3_L = unet_layer_left(Level_2_L, n_filters=64, ker_size_1=2, strides_1=2, ker_size_2=3, strides_2=1, ker_size_3=1, strides_3=1, reg = 0.1)
    Level_4_L = unet_layer_left(Level_3_L, n_filters=128, ker_size_1=2, strides_1=2, ker_size_2=3, strides_2=1, ker_size_3=1, strides_3=1, reg = 0.1)
    Level_5_L = unet_layer_left(Level_4_L, n_filters=256, ker_size_1=2, strides_1=2, ker_size_2=3, strides_2=1, ker_size_3=1, strides_3=1, reg = 0.1)
    Level_6_L = unet_layer_bottleneck(Level_5_L, n_filters= 512, ker_size_1=1, strides_1=1, ker_size_2=3, strides_2=1, reg=0.1)
    Level_5_R = unet_layer_right(Level_6_L, Level_5_L, n_filters=256, ker_size_1=1, strides_1=1, output_pad=None, ker_size_2=3, strides_2=1, ker_size_3=3, strides_3=1, reg=0.1)
    Level_4_R = unet_layer_right(Level_5_R, Level_4_L, n_filters=128, ker_size_1=2, strides_1=2, output_pad=(1,1),ker_size_2=3, strides_2=1, ker_size_3=1, strides_3=1, reg = 0.1)
    Level_3_R = unet_layer_right(Level_4_R, Level_3_L, n_filters=64, ker_size_1=2, strides_1=2, output_pad=None, ker_size_2=3, strides_2=1, ker_size_3=1, strides_3=1, reg = 0.1)
    Level_2_R = unet_layer_right(Level_3_R, Level_2_L, n_filters=32, ker_size_1=2, strides_1=2, output_pad=None, ker_size_2=3, strides_2=1, ker_size_3=1, strides_3=1, reg = 0.1)
    Level_1_R = unet_layer_right(Level_2_R, Level_1_L, n_filters=16, ker_size_1=2, strides_1=2, output_pad=None, ker_size_2=3, strides_2=1, ker_size_3=1, strides_3=1, reg = 0.1)
    output=Conv2D(filters=1,kernel_size=1,strides=1, activation = 'sigmoid', kernel_regularizer=regularizers.l2(0.1))(Level_1_R)
    model=Model(inputs=inputs,outputs=output)
    return model

# %%
model = U_net_adj((200,200,1))

# %%
met = tf.keras.metrics.MeanIoU(num_classes=2) # we choose a built-in metric in keras that is Intersection Over Union
model.compile(optimizer="rmsprop", loss="sparse_categorical_crossentropy") # we define an optimizer and a loss function
model.summary() # print the model
history=model.fit(test_data, test_label, epochs=3,verbose=1) # here we fit the model
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_5 (InputLayer)           [(None, 200, 200, 1  0           []
#                                 )]
#
#  conv2d_94 (Conv2D)             (None, 200, 200, 16  32          ['input_5[0][0]']
#                                 )
#
#  batch_normalization_106 (Batch  (None, 200, 200, 16  64         ['conv2d_94[0][0]']
#  Normalization)                 )
#
#  activation_106 (Activation)    (None, 200, 200, 16  0           ['batch_normalization_106[0][0]']
#                                 )
#
#  spatial_dropout2d_84 (SpatialD  (None, 200, 200, 16  0          ['activation_106[0][0]']
#  ropout2D)                      )
#
#  conv2d_95 (Conv2D)             (None, 200, 200, 16  2320        ['spatial_dropout2d_84[0][0]']
#                                 )
#
#  batch_normalization_107 (Batch  (None, 200, 200, 16  64         ['conv2d_95[0][0]']
#  Normalization)                 )
#
#  activation_107 (Activation)    (None, 200, 200, 16  0           ['batch_normalization_107[0][0]']
#                                 )
#
#  spatial_dropout2d_85 (SpatialD  (None, 200, 200, 16  0          ['activation_107[0][0]']
#  ropout2D)                      )
#
#  conv2d_96 (Conv2D)             (None, 200, 200, 16  272         ['spatial_dropout2d_85[0][0]']
#                                 )
#
#  batch_normalization_108 (Batch  (None, 200, 200, 16  64         ['conv2d_96[0][0]']
#  Normalization)                 )
#
#  add_36 (Add)                   (None, 200, 200, 16  0           ['batch_normalization_108[0][0]',
#                                 )                                 'batch_normalization_106[0][0]']
#
#  activation_108 (Activation)    (None, 200, 200, 16  0           ['add_36[0][0]']
#                                 )
#
#  spatial_dropout2d_86 (SpatialD  (None, 200, 200, 16  0          ['activation_108[0][0]']
#  ropout2D)                      )
#
#  conv2d_97 (Conv2D)             (None, 100, 100, 32  2080        ['spatial_dropout2d_86[0][0]']
#                                 )
#
#  batch_normalization_109 (Batch  (None, 100, 100, 32  128        ['conv2d_97[0][0]']
#  Normalization)                 )
#
#  activation_109 (Activation)    (None, 100, 100, 32  0           ['batch_normalization_109[0][0]']
#                                 )
#
#  spatial_dropout2d_87 (SpatialD  (None, 100, 100, 32  0          ['activation_109[0][0]']
#  ropout2D)                      )
#
#  conv2d_98 (Conv2D)             (None, 100, 100, 32  9248        ['spatial_dropout2d_87[0][0]']
#                                 )
#
#  batch_normalization_110 (Batch  (None, 100, 100, 32  128        ['conv2d_98[0][0]']
#  Normalization)                 )
#
#  activation_110 (Activation)    (None, 100, 100, 32  0           ['batch_normalization_110[0][0]']
#                                 )
#
#  spatial_dropout2d_88 (SpatialD  (None, 100, 100, 32  0          ['activation_110[0][0]']
#  ropout2D)                      )
#
#  conv2d_99 (Conv2D)             (None, 100, 100, 32  1056        ['spatial_dropout2d_88[0][0]']
#                                 )
#
#  batch_normalization_111 (Batch  (None, 100, 100, 32  128        ['conv2d_99[0][0]']
#  Normalization)                 )
#
#  add_37 (Add)                   (None, 100, 100, 32  0           ['batch_normalization_111[0][0]',
#                                 )                                 'batch_normalization_109[0][0]']
#
#  activation_111 (Activation)    (None, 100, 100, 32  0           ['add_37[0][0]']
#                                 )
#
#  spatial_dropout2d_89 (SpatialD  (None, 100, 100, 32  0          ['activation_111[0][0]']
#  ropout2D)                      )
#
#  conv2d_100 (Conv2D)            (None, 50, 50, 64)   8256        ['spatial_dropout2d_89[0][0]']
#
#  batch_normalization_112 (Batch  (None, 50, 50, 64)  256         ['conv2d_100[0][0]']
#  Normalization)
#
#  activation_112 (Activation)    (None, 50, 50, 64)   0           ['batch_normalization_112[0][0]']
#
#  spatial_dropout2d_90 (SpatialD  (None, 50, 50, 64)  0           ['activation_112[0][0]']
#  ropout2D)
#
#  conv2d_101 (Conv2D)            (None, 50, 50, 64)   36928       ['spatial_dropout2d_90[0][0]']
#
#  batch_normalization_113 (Batch  (None, 50, 50, 64)  256         ['conv2d_101[0][0]']
#  Normalization)
#
#  activation_113 (Activation)    (None, 50, 50, 64)   0           ['batch_normalization_113[0][0]']
#
#  spatial_dropout2d_91 (SpatialD  (None, 50, 50, 64)  0           ['activation_113[0][0]']
#  ropout2D)
#
#  conv2d_102 (Conv2D)            (None, 50, 50, 64)   4160        ['spatial_dropout2d_91[0][0]']
#
#  batch_normalization_114 (Batch  (None, 50, 50, 64)  256         ['conv2d_102[0][0]']
#  Normalization)
#
#  add_38 (Add)                   (None, 50, 50, 64)   0           ['batch_normalization_114[0][0]',
#                                                                   'batch_normalization_112[0][0]']
#
#  activation_114 (Activation)    (None, 50, 50, 64)   0           ['add_38[0][0]']
#
#  spatial_dropout2d_92 (SpatialD  (None, 50, 50, 64)  0           ['activation_114[0][0]']
#  ropout2D)
#
#  conv2d_103 (Conv2D)            (None, 25, 25, 128)  32896       ['spatial_dropout2d_92[0][0]']
#
#  batch_normalization_115 (Batch  (None, 25, 25, 128)  512        ['conv2d_103[0][0]']
#  Normalization)
#
#  activation_115 (Activation)    (None, 25, 25, 128)  0           ['batch_normalization_115[0][0]']
#
#  spatial_dropout2d_93 (SpatialD  (None, 25, 25, 128)  0          ['activation_115[0][0]']
#  ropout2D)
#
#  conv2d_104 (Conv2D)            (None, 25, 25, 128)  147584      ['spatial_dropout2d_93[0][0]']
#
#  batch_normalization_116 (Batch  (None, 25, 25, 128)  512        ['conv2d_104[0][0]']
#  Normalization)
#
#  activation_116 (Activation)    (None, 25, 25, 128)  0           ['batch_normalization_116[0][0]']
#
#  spatial_dropout2d_94 (SpatialD  (None, 25, 25, 128)  0          ['activation_116[0][0]']
#  ropout2D)
#
#  conv2d_105 (Conv2D)            (None, 25, 25, 128)  16512       ['spatial_dropout2d_94[0][0]']
#
#  batch_normalization_117 (Batch  (None, 25, 25, 128)  512        ['conv2d_105[0][0]']
#  Normalization)
#
#  add_39 (Add)                   (None, 25, 25, 128)  0           ['batch_normalization_117[0][0]',
#                                                                   'batch_normalization_115[0][0]']
#
#  activation_117 (Activation)    (None, 25, 25, 128)  0           ['add_39[0][0]']
#
#  spatial_dropout2d_95 (SpatialD  (None, 25, 25, 128)  0          ['activation_117[0][0]']
#  ropout2D)
#
#  conv2d_106 (Conv2D)            (None, 12, 12, 256)  131328      ['spatial_dropout2d_95[0][0]']
#
#  batch_normalization_118 (Batch  (None, 12, 12, 256)  1024       ['conv2d_106[0][0]']
#  Normalization)
#
#  activation_118 (Activation)    (None, 12, 12, 256)  0           ['batch_normalization_118[0][0]']
#
#  spatial_dropout2d_96 (SpatialD  (None, 12, 12, 256)  0          ['activation_118[0][0]']
#  ropout2D)
#
#  conv2d_107 (Conv2D)            (None, 12, 12, 256)  590080      ['spatial_dropout2d_96[0][0]']
#
#  batch_normalization_119 (Batch  (None, 12, 12, 256)  1024       ['conv2d_107[0][0]']
#  Normalization)
#
#  activation_119 (Activation)    (None, 12, 12, 256)  0           ['batch_normalization_119[0][0]']
#
#  spatial_dropout2d_97 (SpatialD  (None, 12, 12, 256)  0          ['activation_119[0][0]']
#  ropout2D)
#
#  conv2d_108 (Conv2D)            (None, 12, 12, 256)  65792       ['spatial_dropout2d_97[0][0]']
#
#  batch_normalization_120 (Batch  (None, 12, 12, 256)  1024       ['conv2d_108[0][0]']
#  Normalization)
#
#  add_40 (Add)                   (None, 12, 12, 256)  0           ['batch_normalization_120[0][0]',
#                                                                   'batch_normalization_118[0][0]']
#
#  activation_120 (Activation)    (None, 12, 12, 256)  0           ['add_40[0][0]']
#
#  spatial_dropout2d_98 (SpatialD  (None, 12, 12, 256)  0          ['activation_120[0][0]']
#  ropout2D)
#
#  conv2d_109 (Conv2D)            (None, 12, 12, 512)  131584      ['spatial_dropout2d_98[0][0]']
#
#  batch_normalization_121 (Batch  (None, 12, 12, 512)  2048       ['conv2d_109[0][0]']
#  Normalization)
#
#  activation_121 (Activation)    (None, 12, 12, 512)  0           ['batch_normalization_121[0][0]']
#
#  conv2d_110 (Conv2D)            (None, 12, 12, 512)  2359808     ['activation_121[0][0]']
#
#  batch_normalization_122 (Batch  (None, 12, 12, 512)  2048       ['conv2d_110[0][0]']
#  Normalization)
#
#  add_41 (Add)                   (None, 12, 12, 512)  0           ['batch_normalization_122[0][0]',
#                                                                   'batch_normalization_121[0][0]']
#
#  activation_122 (Activation)    (None, 12, 12, 512)  0           ['add_41[0][0]']
#
#  conv2d_transpose_14 (Conv2DTra  (None, 12, 12, 256)  131328     ['activation_122[0][0]']
#  nspose)
#
#  batch_normalization_123 (Batch  (None, 12, 12, 256)  1024       ['conv2d_transpose_14[0][0]']
#  Normalization)
#
#  activation_123 (Activation)    (None, 12, 12, 256)  0           ['batch_normalization_123[0][0]']
#
#  concatenate_14 (Concatenate)   (None, 12, 12, 512)  0           ['spatial_dropout2d_98[0][0]',
#                                                                   'activation_123[0][0]']
#
#  conv2d_111 (Conv2D)            (None, 12, 12, 256)  1179904     ['concatenate_14[0][0]']
#
#  batch_normalization_124 (Batch  (None, 12, 12, 256)  1024       ['conv2d_111[0][0]']
#  Normalization)
#
#  activation_124 (Activation)    (None, 12, 12, 256)  0           ['batch_normalization_124[0][0]']
#
#  spatial_dropout2d_99 (SpatialD  (None, 12, 12, 256)  0          ['activation_124[0][0]']
#  ropout2D)
#
#  conv2d_112 (Conv2D)            (None, 12, 12, 256)  590080      ['spatial_dropout2d_99[0][0]']
#
#  batch_normalization_125 (Batch  (None, 12, 12, 256)  1024       ['conv2d_112[0][0]']
#  Normalization)
#
#  add_42 (Add)                   (None, 12, 12, 256)  0           ['batch_normalization_125[0][0]',
#                                                                   'batch_normalization_123[0][0]']
#
#  activation_125 (Activation)    (None, 12, 12, 256)  0           ['add_42[0][0]']
#
#  spatial_dropout2d_100 (Spatial  (None, 12, 12, 256)  0          ['activation_125[0][0]']
#  Dropout2D)
#
#  conv2d_transpose_15 (Conv2DTra  (None, 25, 25, 128)  131200     ['spatial_dropout2d_100[0][0]']
#  nspose)
#
#  batch_normalization_126 (Batch  (None, 25, 25, 128)  512        ['conv2d_transpose_15[0][0]']
#  Normalization)
#
#  activation_126 (Activation)    (None, 25, 25, 128)  0           ['batch_normalization_126[0][0]']
#
#  concatenate_15 (Concatenate)   (None, 25, 25, 256)  0           ['spatial_dropout2d_95[0][0]',
#                                                                   'activation_126[0][0]']
#
#  conv2d_113 (Conv2D)            (None, 25, 25, 128)  295040      ['concatenate_15[0][0]']
#
#  batch_normalization_127 (Batch  (None, 25, 25, 128)  512        ['conv2d_113[0][0]']
#  Normalization)
#
#  activation_127 (Activation)    (None, 25, 25, 128)  0           ['batch_normalization_127[0][0]']
#
#  spatial_dropout2d_101 (Spatial  (None, 25, 25, 128)  0          ['activation_127[0][0]']
#  Dropout2D)
#
#  conv2d_114 (Conv2D)            (None, 25, 25, 128)  16512       ['spatial_dropout2d_101[0][0]']
#
#  batch_normalization_128 (Batch  (None, 25, 25, 128)  512        ['conv2d_114[0][0]']
#  Normalization)
#
#  add_43 (Add)                   (None, 25, 25, 128)  0           ['batch_normalization_128[0][0]',
#                                                                   'batch_normalization_126[0][0]']
#
#  activation_128 (Activation)    (None, 25, 25, 128)  0           ['add_43[0][0]']
#
#  spatial_dropout2d_102 (Spatial  (None, 25, 25, 128)  0          ['activation_128[0][0]']
#  Dropout2D)
#
#  conv2d_transpose_16 (Conv2DTra  (None, 50, 50, 64)  32832       ['spatial_dropout2d_102[0][0]']
#  nspose)
#
#  batch_normalization_129 (Batch  (None, 50, 50, 64)  256         ['conv2d_transpose_16[0][0]']
#  Normalization)
#
#  activation_129 (Activation)    (None, 50, 50, 64)   0           ['batch_normalization_129[0][0]']
#
#  concatenate_16 (Concatenate)   (None, 50, 50, 128)  0           ['spatial_dropout2d_92[0][0]',
#                                                                   'activation_129[0][0]']
#
#  conv2d_115 (Conv2D)            (None, 50, 50, 64)   73792       ['concatenate_16[0][0]']
#
#  batch_normalization_130 (Batch  (None, 50, 50, 64)  256         ['conv2d_115[0][0]']
#  Normalization)
#
#  activation_130 (Activation)    (None, 50, 50, 64)   0           ['batch_normalization_130[0][0]']
#
#  spatial_dropout2d_103 (Spatial  (None, 50, 50, 64)  0           ['activation_130[0][0]']
#  Dropout2D)
#
#  conv2d_116 (Conv2D)            (None, 50, 50, 64)   4160        ['spatial_dropout2d_103[0][0]']
#
#  batch_normalization_131 (Batch  (None, 50, 50, 64)  256         ['conv2d_116[0][0]']
#  Normalization)
#
#  add_44 (Add)                   (None, 50, 50, 64)   0           ['batch_normalization_131[0][0]',
#                                                                   'batch_normalization_129[0][0]']
#
#  activation_131 (Activation)    (None, 50, 50, 64)   0           ['add_44[0][0]']
#
#  spatial_dropout2d_104 (Spatial  (None, 50, 50, 64)  0           ['activation_131[0][0]']
#  Dropout2D)
#
#  conv2d_transpose_17 (Conv2DTra  (None, 100, 100, 32  8224       ['spatial_dropout2d_104[0][0]']
#  nspose)                        )
#
#  batch_normalization_132 (Batch  (None, 100, 100, 32  128        ['conv2d_transpose_17[0][0]']
#  Normalization)                 )
#
#  activation_132 (Activation)    (None, 100, 100, 32  0           ['batch_normalization_132[0][0]']
#                                 )
#
#  concatenate_17 (Concatenate)   (None, 100, 100, 64  0           ['spatial_dropout2d_89[0][0]',
#                                 )                                 'activation_132[0][0]']
#
#  conv2d_117 (Conv2D)            (None, 100, 100, 32  18464       ['concatenate_17[0][0]']
#                                 )
#
#  batch_normalization_133 (Batch  (None, 100, 100, 32  128        ['conv2d_117[0][0]']
#  Normalization)                 )
#
#  activation_133 (Activation)    (None, 100, 100, 32  0           ['batch_normalization_133[0][0]']
#                                 )
#
#  spatial_dropout2d_105 (Spatial  (None, 100, 100, 32  0          ['activation_133[0][0]']
#  Dropout2D)                     )
#
#  conv2d_118 (Conv2D)            (None, 100, 100, 32  1056        ['spatial_dropout2d_105[0][0]']
#                                 )
#
#  batch_normalization_134 (Batch  (None, 100, 100, 32  128        ['conv2d_118[0][0]']
#  Normalization)                 )
#
#  add_45 (Add)                   (None, 100, 100, 32  0           ['batch_normalization_134[0][0]',
#                                 )                                 'batch_normalization_132[0][0]']
#
#  activation_134 (Activation)    (None, 100, 100, 32  0           ['add_45[0][0]']
#                                 )
#
#  spatial_dropout2d_106 (Spatial  (None, 100, 100, 32  0          ['activation_134[0][0]']
#  Dropout2D)                     )
#
#  conv2d_transpose_18 (Conv2DTra  (None, 200, 200, 16  2064       ['spatial_dropout2d_106[0][0]']
#  nspose)                        )
#
#  batch_normalization_135 (Batch  (None, 200, 200, 16  64         ['conv2d_transpose_18[0][0]']
#  Normalization)                 )
#
#  activation_135 (Activation)    (None, 200, 200, 16  0           ['batch_normalization_135[0][0]']
#                                 )
#
#  concatenate_18 (Concatenate)   (None, 200, 200, 32  0           ['spatial_dropout2d_86[0][0]',
#                                 )                                 'activation_135[0][0]']
#
#  conv2d_119 (Conv2D)            (None, 200, 200, 16  4624        ['concatenate_18[0][0]']
#                                 )
#
#  batch_normalization_136 (Batch  (None, 200, 200, 16  64         ['conv2d_119[0][0]']
#  Normalization)                 )
#
#  activation_136 (Activation)    (None, 200, 200, 16  0           ['batch_normalization_136[0][0]']
#                                 )
#
#  spatial_dropout2d_107 (Spatial  (None, 200, 200, 16  0          ['activation_136[0][0]']
#  Dropout2D)                     )
#
#  conv2d_120 (Conv2D)            (None, 200, 200, 16  272         ['spatial_dropout2d_107[0][0]']
#                                 )
#
#  batch_normalization_137 (Batch  (None, 200, 200, 16  64         ['conv2d_120[0][0]']
#  Normalization)                 )
#
#  add_46 (Add)                   (None, 200, 200, 16  0           ['batch_normalization_137[0][0]',
#                                 )                                 'batch_normalization_135[0][0]']
#
#  activation_137 (Activation)    (None, 200, 200, 16  0           ['add_46[0][0]']
#                                 )
#
#  spatial_dropout2d_108 (Spatial  (None, 200, 200, 16  0          ['activation_137[0][0]']
#  Dropout2D)                     )
#
#  conv2d_121 (Conv2D)            (None, 200, 200, 1)  17          ['spatial_dropout2d_108[0][0]']
#
# ==================================================================================================
# Total params: 6,045,505
# Trainable params: 6,037,505
# Non-trainable params: 8,000
# __________________________________________________________________________________________________
# Epoch 1/3
# 1/1 [==============================] - 8s 8s/step - loss: 1507.4918
# Epoch 2/3
# 1/1 [==============================] - 0s 35ms/step - loss: 1361.4635
# Epoch 3/3
# 1/1 [==============================] - 0s 45ms/step - loss: 1265.8076

# %% [markdown]
# # As we made for the data generator, we need to save this code to a .py in order to make it callable by another piece of code. Please call the file UNET_architecture.py
